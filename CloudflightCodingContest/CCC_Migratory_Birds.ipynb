# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2a90e158-b736-4038-8492-6f2a25e81727" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a90e158-b736-4038-8492-6f2a25e81727">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip 'level-1.zip'
# !rm 'level-1.zip'
# Out:
# Archive:  level-1.zip
# replace in_level-1_0-example.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: in_level-1_0-example.txt
# replace in_level-1_1-a.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# # LEVEL 1

# %%
import numpy as np
import pandas as pd

# %%
# Level 1-a
df1 = pd.read_csv('in_level-1_1-a.txt')

# %%
df1['Temperature [°C]'] = df1['Temperature [°C]'].replace('seventeen', 17)
df1['Temperature [°C]'] = df1['Temperature [°C]'].astype('int64')

# %%
df1['Temperature [°C]'] = df1['Temperature [°C]'].astype('int64')

# %%
df1.sort_values(by=['Temperature [°C]'])
# Out:
#    BOP  Temperature [°C]  Humidity [%]
# 2    3                 6            77
# 3    4                17            89
# 0    1                22            72
# 4    5                28            42
# 1    2                32            39

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BOP               5 non-null      int64
#  1   Temperature [°C]  5 non-null      object
#  2   Humidity [%]      5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
# Level 1-b
df2 = pd.read_csv('in_level-1_2-b.txt')
list2 = df2.sort_values(by='Temperature [°C]', ascending=False)['BOP'].tolist()
list2 = list(map(str, list2))

# %%
with open('submission2.txt', 'w') as file:
  file.write(" ".join(list2))

files.download('submission2.txt')

# %%
# Level 1-c
df3 = pd.read_csv('in_level-1_3-c.txt')

# %%
sorted_temp = df3.sort_values(by=['Temperature [°C]', 'Humidity [%]'], ascending=[False, True])

# %%
sorted_temp
# Out:
#      BOP  Temperature [°C]  Humidity [%]
# 145  201                43            40
# 138  194                43            58
# 58   106                41            52
# 126  181                41            65
# 185  247                40            16
# ..   ...               ...           ...
# 152  210                -2            15
# 166  224                -2            42
# 67   115                -2            73
# 37    80                -2            84
# 66   114                -3            60
#
# [200 rows x 3 columns]

# %%
sorted_temp = sorted_temp['BOP'].tolist()
sorted_temp = list(map(str, sorted_temp))
" ".join(sorted_temp)

# %%
with open('submission3.txt', 'w') as s3:
  s3.write(" ".join(sorted_temp))

files.download('submission3.txt')

# %%
# Level 1-d
df4 = pd.read_csv('in_level-1_4-d.txt')

# %%
df4.head()
# Out:
#    BOP  Temperature [°C]  Humidity [%]
# 0  269                19            33
# 1  285                19            58
# 2  327                19            35
# 3  355                19             7
# 4  400                19            76

# %%
df4['Temperature [°C]'].describe()
# Out:
# count    73.0
# mean     19.0
# std       0.0
# min      19.0
# 25%      19.0
# 50%      19.0
# 75%      19.0
# max      19.0
# Name: Temperature [°C], dtype: float64

# %%
sorted_temp = df4.sort_values(by=['Temperature [°C]', 'Humidity [%]'], ascending=[False, True])

# %%
sorted_temp
# Out:
#      BOP  Temperature [°C]  Humidity [%]
# 3    355                19             7
# 56  2125                19             7
# 70  2472                19             9
# 20   865                19            11
# 71  2473                19            11
# ..   ...               ...           ...
# 53  2058                19            81
# 21   892                19            89
# 43  1824                19            89
# 59  2161                19            90
# 27  1116                19            94
#
# [73 rows x 3 columns]

# %%
sorted_temp = sorted_temp['BOP'].tolist()
sorted_temp = list(map(str, sorted_temp))
" ".join(sorted_temp)
# Out:
# '355 2125 2472 865 2473 1067 2066 2160 490 1810 912 781 1436 2388 733 2495 1193 2162 1449 438 269 437 2421 327 1903 636 1816 2191 1972 2272 958 1994 2069 2398 1023 1850 619 1350 1789 2309 650 742 1971 2440 1612 1386 1563 285 2266 764 782 1148 1887 1913 2158 1838 760 2044 1362 518 816 2308 680 956 400 1169 1521 1817 2058 892 1824 2161 1116'

# %%
with open('submission4.txt', 'w') as s4:
  s4.write(" ".join(sorted_temp))

files.download('submission4.txt')

# %%
# Level 1-e
df5 = pd.read_csv('in_level-1_5-e.txt')

# %%
df5['Temperature [°C]'] = df5['Temperature [°C]'].replace('seventeen', 17)
df5['Temperature [°C]'] = df5['Temperature [°C]'].astype('int64')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2171 entries, 0 to 2170
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BOP               2171 non-null   int64
#  1   Temperature [°C]  2171 non-null   int64
#  2   Humidity [%]      2171 non-null   int64
# dtypes: int64(3)
# memory usage: 51.0 KB

# %%
df5['Temperature [°C]'].describe()
# Out:
# count    2171.000000
# mean       39.853984
# std        36.325644
# min        -5.000000
# 25%        10.000000
# 50%        22.000000
# 75%        79.000000
# max       113.000000
# Name: Temperature [°C], dtype: float64

# %%
df5.head()
# Out:
#    BOP  Temperature [°C]  Humidity [%]
# 0  130                88            83
# 1  193                 2            12
# 2  202                22            69
# 3  203                 6            56
# 4  225                20            47

# %%
sorted_temp = df5.sort_values(by=['Temperature [°C]', 'Humidity [%]'], ascending=[False, True])

# %%
sorted_temp
# Out:
#        BOP  Temperature [°C]  Humidity [%]
# 2036  2359               113            13
# 1638  1944               113            22
# 1187  1480               113            37
# 1709  2018               113            40
# 1351  1647               111            16
# ...    ...               ...           ...
# 1759  2072                -5            47
# 777   1060                -5            60
# 1701  2010                -5            65
# 1698  2007                -5            66
# 1075  1365                -5            76
#
# [2171 rows x 3 columns]

# %%
sorted_temp = sorted_temp['BOP'].tolist()
sorted_temp = list(map(str, sorted_temp))
" ".join(sorted_temp)
# Out:
# '2359 1944 1480 2018 1647 1330 2260 1509 535 1259 533 1041 882 1585 909 1644 1131 272 1768 2187 2002 786 614 358 1553 2061 2104 1034 2401 2036 914 575 1144 1417 325 788 1045 1764 2032 1413 1566 983 1056 1186 1039 2386 1337 2385 1645 1508 633 1581 1398 1336 2486 2202 1776 485 1158 256 1471 1650 1318 363 2099 1080 2152 2118 1686 1345 1638 1784 959 546 1849 1120 2193 410 869 936 2062 572 311 1935 1312 1781 1831 2234 1562 1030 1092 2442 2151 1196 501 2476 831 1227 745 1301 338 1682 474 791 383 2282 1343 1004 943 345 464 2294 1806 1579 1900 1937 1499 2012 2443 1858 669 1592 2493 1908 519 2174 1529 945 2345 1266 1967 2496 2130 857 987 1407 1928 2240 2123 1963 1515 591 460 2015 1309 264 2310 2305 1483 1794 792 551 2350 677 646 600 2221 2102 540 658 2447 1872 939 2133 498 1870 473 2244 2319 2436 1705 2410 396 530 2406 878 777 1257 1618 1748 2009 404 1099 1207 1615 1260 1620 2248 1347 1719 397 1412 1538 2048 961 2392 2253 439 1958 1489 2340 1629 2255 921 928 333 2215 2358 1138 1815 477 1411 2
# ...

# %%
with open('submission5.txt', 'w') as s5:
  s5.write(" ".join(sorted_temp))

files.download('submission5.txt')

# %% [markdown]
# # LEVEL 2
